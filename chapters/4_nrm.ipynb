# %% [markdown]
# # 1. Вариации на тему НРМ

# %% [markdown]
# Неравномерно-районированная модель города была предложена Александром Аркадьевичем Высоковским и описывает развитие городской территории как изначально неоднородный процесс. Согласно этой концепции, рост и концентрация функций обычно тяготеют к основному центру города — чаще всего историческому ядру. В то же время на периферии возникают вторичные очаги городской активности: локальные центры, ориентированные на повседневные нужды жителей — торговлю, услуги, рабочие места и социальную инфраструктуру.
#
# В этом разделе мы не будем подробно рассматривать модель. А лишь выполним одно небольшое "упражнение", которое покажет один из возможных подходов выделения локальных центров на основе выборки данных.

# %% [markdown]
# ## 0. Подготовка данных

# %% [markdown]
# Импортируем библиотеки

# %%
import geopandas as gpd

import osmnx as ox


from libpysal.weights import Queen
from pysal.lib import weights

# %% [markdown]
# **Загружаем данные о плотности населения Краснодара, агрегированные по квадратной сетке регулярных ячеек**

# %%
sq_grid = gpd.read_file('./data/krs_pop_sqgrid.geojson')

sq_grid.explore(tiles='cartodbpositron')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9364b265ce8280f8c8dc8d7c1a9a036 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9364b265ce8280f8c8dc8d7c1a9a036&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9364b265ce8280f8c8dc8d7c1a9a036 = L.map(
#                 &quot;map_f9364b265ce8280f8c8dc8d7c1a9a036&quot;,
#                 {
#                     center: [45.0893743349439, 39.02204421607294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_f9364b265ce8280f8c8dc8d7c1a9a036);
#
#
#
#
#
#             var tile_layer_1ed36bffbd303d1feb6db7e4386f0728 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f9364b265ce8280f8c8dc8d7c1a9a036);
#
#
#             map_f9364b265ce8280f8c8dc8d7c1a9a036.fitBounds(
#                 [[44.958505250153884, 38.64631323028552], [45.220243419733904, 39.39777520186036]],
#                 {}
#             );
#
#
#         function geo_json_442d10d20fa43697923e4c15d98180b4_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_442d10d20fa43697923e4c15d98180b4_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_442d10d20fa43697923e4c15d98180b4_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_442d10d20fa43697923e4c15d98180b4_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_442d10d20fa43697923e4c15d98180b4_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_442d10d20fa43697923e4c15d98180b4.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_442d10d20fa43697923e4c15d98180b4_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_442d10d20fa43697923e4c15d98180b4 = L.geoJson(null, {
#                 onEachFeature: geo_json_442d10d20fa43697923e4c15d98180b4_onEachFeature,
#
#                 style: geo_json_442d10d20fa43697923e4c15d98180b4_styler,
#                 pointToLayer: geo_json_442d10d20fa43697923e4c15d98180b4_pointToLayer
#         });
#
#         function geo_json_442d10d20fa43697923e4c15d98180b4_add (data) {
#             geo_json_442d10d20fa43697923e4c15d98180b4
#                 .addData(data)
#                 .addTo(map_f9364b265ce8280f8c8dc8d7c1a9a036);
#         }
#             geo_json_442d10d20fa43697923e4c15d98180b4_add({&quot;bbox&quot;: [38.64631323028552, 44.958505250153884, 39.39777520186036, 45.220243419733904], &quot;features&quot;: [{&quot;bbox&quot;: [38.64631323028552, 45.21069440334368, 38.65910344568596, 45.219734549653424], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[38.64631323028552, 45.219695818051036], [38.659049660383076, 45.219734549653424], [38.65910344568596, 45.210733122859544], [38.64636902467448, 45.21069440334368], [38.64631323028552, 45.219695818051036]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;build_pop_sum&quot;: null, &quot;id&quot;: 1, &quot;pop_density&quot;: null}, &quot;type&quo

# %% [markdown]
# Записывем СК сетки в переменную и название города, с которым мы работаем

# %%
krs_crs = sq_grid.estimate_utm_crs()
place="Krasnodar city"

# %% [markdown]
# **Загружаем точки торговли из osm**

# %%
tags_retail = {
    'shop': [
        'supermarket',
        'convenience',
        'grocery'
    ]
}

retail = ox.features_from_place(place, tags_retail)

retail.explore(tiles='cartodbpositron')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_44964a0b02b4771a59461728de86f1bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_44964a0b02b4771a59461728de86f1bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_44964a0b02b4771a59461728de86f1bb = L.map(
#                 &quot;map_44964a0b02b4771a59461728de86f1bb&quot;,
#                 {
#                     center: [45.0686507, 39.01866955],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_44964a0b02b4771a59461728de86f1bb);
#
#
#
#
#
#             var tile_layer_5c006be882f32a2b584c86d9e6646406 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_44964a0b02b4771a59461728de86f1bb);
#
#
#             map_44964a0b02b4771a59461728de86f1bb.fitBounds(
#                 [[44.9918544, 38.8627786], [45.145447, 39.1745605]],
#                 {}
#             );
#
#
#         function geo_json_7e9a69695ca939806821a097757ca75f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_7e9a69695ca939806821a097757ca75f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_7e9a69695ca939806821a097757ca75f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_7e9a69695ca939806821a097757ca75f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_7e9a69695ca939806821a097757ca75f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_7e9a69695ca939806821a097757ca75f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_7e9a69695ca939806821a097757ca75f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_7e9a69695ca939806821a097757ca75f = L.geoJson(null, {
#                 onEachFeature: geo_json_7e9a69695ca939806821a097757ca75f_onEachFeature,
#
#                 style: geo_json_7e9a69695ca939806821a097757ca75f_styler,
#                 pointToLayer: geo_json_7e9a69695ca939806821a097757ca75f_pointToLayer
#         });
#
#         function geo_json_7e9a69695ca939806821a097757ca75f_add (data) {
#             geo_json_7e9a69695ca939806821a097757ca75f
#                 .addData(data)
#                 .addTo(map_44964a0b02b4771a59461728de86f1bb);
#         }
#             geo_json_7e9a69695ca939806821a097757ca75f_add({&quot;bbox&quot;: [38.8627786, 44.9918544, 39.1745605, 45.145447], &quot;features&quot;: [{&quot;bbox&quot;: [39.0018099, 45.066869, 39.0018099, 45.066869], &quot;geometry&quot;: {&quot;coordinates&quot;: [39.0018099, 45.066869], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;(\u0027node\u0027, 343373481)&quot;, &quot;properties&quot;: {&quot;addr1:housenumber&quot;: null, &quot;addr1:street&quot;: null, &quot;addr2:housenumber&quot;: null, &quot;addr2:street&quot;: null, &quot;addr:city&quot;: null, &quot;addr:country&quot;: null, &quot;addr:floor&quot;: null, &quot;addr:housenumber&quot;: null, &quot;addr:place&quot;: null, &quot;addr:postcode&quot;: null, &quot;addr:region&quot;: null, &q

# %% [markdown]
# **Фильтруем данные и считаем количество точек по ячейкам регулярной сетки**

# %%
retail_pts = retail[retail.geometry.type == "Point"].copy()

# убираем пустые геометрии
retail_pts = retail_pts[~retail_pts.geometry.is_empty & retail_pts.geometry.notna()].copy()

# перепроецируем в UTM-зону
retail_pts = retail_pts.to_crs(krs_crs)

# объединяем с ячейками сетки
join = gpd.sjoin(
    retail_pts[["geometry"]],
    sq_grid[["geometry"]],
    how="left",
    predicate="within"
)

# считаем количество точек по каждой ячейке
counts = join.groupby("index_right").size().rename("retail_cnt")

# записываем посчитанное в исходную сетку
sq_grid["retail_cnt"] = sq_grid.index.map(counts)

# смотрим на результат
sq_grid.explore(column="retail_cnt", tiles='cartodbpositron',
        missing_kwds={
        "color": "lightgrey",
        "label": "No data"
    })
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b87b61be644c72a5193454891a7fbaed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend &#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:lightgrey&#x27;&gt;&lt;/span&gt;No data&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b87b61be644c72a5193454891a7fbaed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b87b61be644c72a5193454891a7fbaed = L.map(
#                 &quot;map_b87b61be644c72a5193454891a7fbaed&quot;,
#                 {
#                     center: [45.0893743349439, 39.02204421607294],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b87b61be644c72a5193454891a7fbaed);
#
#
#
#
#
#             var tile_layer_6d7e3e2365895d4daba3247dabe62d5f = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b87b61be644c72a5193454891a7fbaed);
#
#
#             map_b87b61be644c72a5193454891a7fbaed.fitBounds(
#                 [[44.958505250153884, 38.64631323028552], [45.220243419733904, 39.39777520186036]],
#                 {}
#             );
#
#
#         function geo_json_655ce56672812093eb9f6be295ae873a_styler(feature) {
#             switch(feature.id) {
#                 case &quot;565&quot;: case &quot;590&quot;: case &quot;598&quot;: case &quot;625&quot;: case &quot;678&quot;: case &quot;679&quot;: case &quot;680&quot;: case &quot;683&quot;: case &quot;734&quot;: case &quot;795&quot;: case &quot;822&quot;: case &quot;851&quot;: case &quot;880&quot;: case &quot;883&quot;: case &quot;912&quot;: case &quot;915&quot;: case &quot;916&quot;: case &quot;941&quot;: case &quot;951&quot;: case &quot;978&quot;: case &quot;1066&quot;: case &quot;1092&quot;: case &quot;1096&quot;: case &quot;1122&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;566&quot;: case &quot;597&quot;: case &quot;656&quot;: case &quot;685&quot;: case &quot;708&quot;: case &quot;712&quot;: case &quot;717&quot;: case &quot;735&quot;: case &quot;736&quot;: case &quot;766&quot;: case &quot;768&quot;: case &qu

# %% [markdown]
# Оставляем только ячейки внутри Краснодара

# %%
krs_border = ox.geocode_to_gdf(place)
krs_border_utm = krs_border.to_crs(krs_crs)

krs_grid = sq_grid[sq_grid.intersects(krs_border_utm.geometry.iloc[0])].copy()

krs_grid.explore(column="retail_cnt", tiles='cartodbpositron')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e5c80ddee649336193477f962a3008d4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e5c80ddee649336193477f962a3008d4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e5c80ddee649336193477f962a3008d4 = L.map(
#                 &quot;map_e5c80ddee649336193477f962a3008d4&quot;,
#                 {
#                     center: [45.05820991366702, 38.97760264142323],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_e5c80ddee649336193477f962a3008d4);
#
#
#
#
#
#             var tile_layer_ae4095826d70bee6d021733db8e5d034 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e5c80ddee649336193477f962a3008d4);
#
#
#             map_e5c80ddee649336193477f962a3008d4.fitBounds(
#                 [[44.95918818749113, 38.76158063058163], [45.15723163984291, 39.19362465226482]],
#                 {}
#             );
#
#
#         function geo_json_06d692d458dd56bbfee33b07212995cb_styler(feature) {
#             switch(feature.id) {
#                 case &quot;565&quot;: case &quot;590&quot;: case &quot;598&quot;: case &quot;625&quot;: case &quot;678&quot;: case &quot;679&quot;: case &quot;680&quot;: case &quot;683&quot;: case &quot;734&quot;: case &quot;795&quot;: case &quot;822&quot;: case &quot;851&quot;: case &quot;880&quot;: case &quot;883&quot;: case &quot;912&quot;: case &quot;915&quot;: case &quot;916&quot;: case &quot;941&quot;: case &quot;951&quot;: case &quot;978&quot;: case &quot;1066&quot;: case &quot;1092&quot;: case &quot;1096&quot;: case &quot;1122&quot;:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;566&quot;: case &quot;597&quot;: case &quot;656&quot;: case &quot;685&quot;: case &quot;708&quot;: case &quot;712&quot;: case &quot;717&quot;: case &quot;735&quot;: case &quot;736&quot;: case &quot;766&quot;: case &quot;768&quot;: case &quot;802&quot;: case &quot;856&quot;: case &quot;864&quot;: case &quot;881&quot;: case &quot;948&quot;: case &quot;950&quot;: case &quot;1005&quot;: case &quot;1010&quot;: case &quot;1034&quot;: case &quot;1036&quot;: case &quot;1038&quot;: case &quot;1093&quot;: case &quot;1206&quot;:
#                     return {&quot;color&quot;: &quot;#471063&quot;, &quot;fillColor&quot;: &quot;#471063&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;569&quot;: case &quot;827&quot;: case &quot;860&quot;:
#                     return {&quot;color&quot;: &quot;#2a788e&quot;, &quot;fillColor&quot;: &quot;#2a788e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;594&quot;: case &quot;686&quot;: case &quot;719&quot;: case &quot;763&quot;: case &quot;764&quot;: case &quot;793&quot;: case &quot;803&quot;: case &quot;862&quot;: case &quot;910&quot;: case &quot;913&quot;: case &quot;979&quot;: case &quot;1006&quot;:
#                     return {&quot;color&quot;: &quot;#453781&quot;, &quot;fillColor&quot;: &quot;#453781&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;599&quot;: case &quot;620&quot;: case &quot;650&quot;: case &quot;651&quot;: case &quot;655&quot;: case &quot;706&quot;: case &quot;720&quot;: case &quot;796&quot;: case &quot;797&quot;: case &quot;800&quot;: case &quot;831&quot;: case &quot;835&quot;: case &quot;855&quot;: case &quot;882&quot;: case &quot;889&quot;: case &quot;890&quot;: case &quot;894&quot;: case &quot;949&quot;: case &quot;982&quot;: case &quot;1007&quot;: case &quot;1063&quot;: case &quot;1064&quot;:
#                     return {&quot;color&quot;: &quot;#481d6f&quot;, &quot;fillColor&quot;: &quot;#481d6f&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;600&quot;: case &quot;714&quot;: case &quot;829&quot;:
#                     return {&quot;color&quot;: &quot;#1f958b&quot;, &quot;fillColor&quot;: &quot;#1f958b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};

# %% [markdown]
# ## 1. Выделение локальных центров

# %% [markdown]
# ### 1.1 Расчёт пространственного лага (среднего значения в соседних ячейках)

# %%
df = krs_grid.copy()

#изучаемое значение
x_col = "retail_cnt"  

# убираем Nan
df[x_col] = df[x_col].fillna(0)

# веса Queen
w = Queen.from_dataframe(df)

print("Number of islands (no neighbors):", len(w.islands))

#row-стандартизация весов
w.transform = "r"

# пространственный лаг 
x = df[x_col].values
wx = weights.lag_spatial(w, x)# Wx_i

df["W_" + x_col] = wx
# Out:
# Number of islands (no neighbors): 0
# /var/folders/ry/9bb7wrz54vq_kn2ytlj6ynzm0000gn/T/ipykernel_63116/907929596.py:10: FutureWarning: `use_index` defaults to False but will default to True in future. Set True/False directly to control this behavior and silence this warning
#   w = Queen.from_dataframe(df)

# %% [markdown]
# ### 1.2 Вычсление отклонений от пространственного лага

# %%
df["dev"] = df[x_col] - df["W_" + x_col]    # d_i = x_i - Wx_i

df.explore(
    column="dev",
    legend=True,
    tiles="cartodbpositron"
)

# %% [markdown]
# ### 1.3 Определение центров

# %%
# стандартизация (z-score)
dev_mean = df["dev"].mean()
dev_std = df["dev"].std(ddof=0)
df["dev_z"] = (df["dev"] - dev_mean) / dev_std

# центры по порогу
df["center_1sd"] = df["dev_z"] >= 1
df["center_2sd"] = df["dev_z"] >= 2

df[["dev", "dev_z", "center_1sd", "center_2sd"]].head()
# Out:
#      dev     dev_z  center_1sd  center_2sd
# 278  0.0  0.014793       False       False
# 279  0.0  0.014793       False       False
# 306  0.0  0.014793       False       False
# 307  0.0  0.014793       False       False
# 308  0.0  0.014793       False       False

# %% [markdown]
# ### 1.4 Изучаем результат

# %%
df["center_type"] = "no center"
df.loc[df["dev_z"] >= 1, "center_type"] = "center (≥1σ)"
df.loc[df["dev_z"] >= 2, "center_type"] = "core center (≥2σ)"

df.explore(
    column="center_type",
    categorical=True,
    legend=True,
    tiles="cartodbpositron",
    tooltip=[x_col, "dev_z"]
)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_742d8e59678b7fb1ec1de80c84a854c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#     &lt;script src=&quot;https://code.jquery.com/ui/1.12.1/jquery-ui.js&quot;&gt;&lt;/script&gt;
#     &lt;script&gt;$( function() {
#         $( &quot;.maplegend&quot; ).draggable({
#             start: function (event, ui) {
#                 $(this).css({
#                     right: &quot;auto&quot;,
#                     top: &quot;auto&quot;,
#                     bottom: &quot;auto&quot;
#                 });
#             }
#         });
#     });
#     &lt;/script&gt;
#     &lt;style type=&#x27;text/css&#x27;&gt;
#       .maplegend {
#         position: absolute;
#         z-index:9999;
#         background-color: rgba(255, 255, 255, .8);
#         border-radius: 5px;
#         box-shadow: 0 0 15px rgba(0,0,0,0.2);
#         padding: 10px;
#         font: 12px/14px Arial, Helvetica, sans-serif;
#         right: 10px;
#         bottom: 20px;
#       }
#       .maplegend .legend-title {
#         text-align: left;
#         margin-bottom: 5px;
#         font-weight: bold;
#         }
#       .maplegend .legend-scale ul {
#         margin: 0;
#         margin-bottom: 0px;
#         padding: 0;
#         float: left;
#         list-style: none;
#         }
#       .maplegend .legend-scale ul li {
#         list-style: none;
#         margin-left: 0;
#         line-height: 16px;
#         margin-bottom: 2px;
#         }
#       .maplegend ul.legend-labels li span {
#         display: block;
#         float: left;
#         height: 14px;
#         width: 14px;
#         margin-right: 5px;
#         margin-left: 0;
#         border: 0px solid #ccc;
#         }
#       .maplegend .legend-source {
#         color: #777;
#         clear: both;
#         }
#       .maplegend a {
#         color: #777;
#         }
#     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#     &lt;div id=&#x27;maplegend center_type&#x27; class=&#x27;maplegend&#x27;&gt;
#         &lt;div class=&#x27;legend-title&#x27;&gt;center_type&lt;/div&gt;
#         &lt;div class=&#x27;legend-scale&#x27;&gt;
#             &lt;ul class=&#x27;legend-labels&#x27;&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#1f77b4&#x27;&gt;&lt;/span&gt;center (≥1σ)&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#8c564b&#x27;&gt;&lt;/span&gt;core center (≥2σ)&lt;/li&gt;
#                 &lt;li&gt;&lt;span style=&#x27;background:#9edae5&#x27;&gt;&lt;/span&gt;no center&lt;/li&gt;
#             &lt;/ul&gt;
#         &lt;/div&gt;
#     &lt;/div&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_742d8e59678b7fb1ec1de80c84a854c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_742d8e59678b7fb1ec1de80c84a854c7 = L.map(
#                 &quot;map_742d8e59678b7fb1ec1de80c84a854c7&quot;,
#                 {
#                     center: [45.05820991366702, 38.97760264142323],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_742d8e59678b7fb1ec1de80c84a854c7);
#
#
#
#
#
#             var tile_layer_8b9ebfcc4e179061e5f075f984f4eb33 = L.tileLayer(
#                 &quot;https://a.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_742d8e59678b7fb1ec1de80c84a854c7);
#
#
#             map_742d8e59678b7fb1ec1de80c84a854c7.fitBounds(
#                 [[44.95918818749113, 38.76158063058163], [45.15723163984291, 39.19362465226482]],
#                 {}
#             );
#
#
#         function geo_json_156caa18d0778aee2643344230e1e151_styler(feature) {
#             switch(feature.id) {
#                 case &quot;569&quot;: case &quot;600&quot;: case &quot;601&quot;: case &quot;629&quot;: case &quot;684&quot;: case &quot;713&quot;: case &quot;741&quot;: case &quot;745&quot;: case &quot;746&quot;: case &quot;772&quot;: case &quot;826&quot;: case &quot;829&quot;: case &quot;859&quot;: case &quot;921&quot;: case &quot;1035&quot;:
#                     return {&quot;color&quot;: &quot;#8c564b&quot;, &quot;fillColor&quot;: &quot;#8c564b&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;594&quot;: case &quot;626&quot;: case &quot;649&quot;: case &quot;687&quot;: case &quot;714&quot;: case &quot;738&quot;: case &quot;773&quot;: case &quot;791&quot;: case &quot;805&quot;: case &quot;824&quot;: case &quot;827&quot;: case &quot;834&quot;: case &quot;860&quot;: case &quot;861&quot;: c
